# %%
#实例1：圆面积的计算
r=25
area=3.1415*r*r
print(area)

# %%
def read_file():

    try:

        print('aaa')

    except:

        print('error occurs while reading file')

    finally:

        print('bbbb')

read_file()

# %%
def createGenerator():
    mylist = range(3)
    for i in mylist:
        yield i*i
        
createGenerator()

# %%
print("{:.2f}".format(area))

# %%
data = """a,b,c
d,e,f
g,h,i
j,k,l"""

# %%
output = data.split('\n')
print(output)

# %%
output = data.split('/n')
print(output)

# %%
output =data.splitlines()  #分隔符，默认为所有的空字符，包括空格、换行(\n)、制表符(\t)等
print(output)

# %%
['a,b,c', 'd,e,f', 'g,h,i', 'j,k,l']

# %%
import pandas as pd
data11=data21=data31=data41=data51=data61=data71=data81\
=data91=data101=data111=data121=data131=data141\
=data151=data161=data171=data181=data191=data201=data211\
= pd.DataFrame(columns=['w','ka','period'])

# %%
76trombones = 'big parade'

# %%
more@ = 1000000

# %%
class = 'Advanced Theoret'

# %%
#实例2：温度转换
# C=(F-32)/1.8
# F=C*1.8+32   其中，C表示摄氏温度，F表示华氏温度

TempStr=input("请输入带有符号的温度值：")
if TempStr[-1] in ['F','f']:
    C=(eval(TempStr[0:-1])-32)/1.8     # eval() 函数用来执行一个字符串表达式，并返回表达式的值。
    print("转换后的温度是{:.2f}C".format(C))
elif TempStr[-1] in ['C','c']:
    F=1.8*eval(TempStr[0:-1])+32
    print("转换后的温度是{:.2f}F".format(F))
else:
    print("输入格式错误")

# %%
eval('2 + 2')
eval('pow(2,2)')

# %%
TempStr = "82F" #向变量赋值

# %%
InputStr="请输入带有符号的温度值："

# %%
InputStr[0]

# %%
InputStr[-1]

# %%
InputStr[0:-1]

# %%
#定义字符串，单引号和双引号没有区别，但如果字符串包括单/双引号，可用转义字符\
my_str1 = 'I\'m a student'
my_str2 = "I'm a student"

my_str3 = "Jason said \"I like you\""
my_str4 = 'Jason said "I like you"'

# %%
faa = 3.1415926
fbb = round(faa,2)
print(fbb)

# %%
s3 = '''abcd'''
print(s3)

# %%
s4 = '''abcd
efgh
ijkl'''
print(s4)

# %%
str3 = 'hello' + 'test'
print(str3)

# %%
str4 = 'w' * 5
print(str4)

# %%
A = [10, 11, 12, 13] # 元素为整数
B = ['red', 'blue', 'green'] # 元素
E = A + B 
print(E)

# %%
a=range(5)
print(a)

# %%
b=range(1,5) # 返回一个整数列表
print(b)

# %%
c=range (1,10,2) #range(start,end,step)
print(c)

# %%
for ii in range(1,10,2):
    print (ii)

# %%
number=[1,2,"a","b",'day']
number2=['physics']
number[0] = 68 # 修改元素值x
print(number)

# %%
number.append(4) # 追加元素
print(number)

# %%
print(number.index('a'))

# %%
number.insert(3, 5) # 插入元素insert
print(number)

# %%
number.extend(number2) # 合并number 
print(number)

# %%
number.pop(0) # 删除第一个值
print(number)

# %%
del number[1] # 删除元素
print(number)

# %%
number.reverse()
print(number)

# %%
aTuple = (1, 3, 5)
print(aTuple)

# %%
f = (2,3,4,5) # 整数序列
g = () # 空序列
h = (2, [3,4], (10,11,12)) #

# %%
x = f[1] # 将f[1] 的元素值赋值
print(x)

# %%
y = f[1:3] # 获得索引为1,2 的元素
print(y)

# %%
z = h[1][1] # 二维数组看待 z = 4
print(z)

# %%
thisset=set(("Google","Runoob","Taobao"))
thisset.add("Facebook")
print(thisset)

# %%
s = set(['A', 'B', 'C'])  #定义set集合
print(s)

# %%
len(s)

# %%
s.remove('B')
print(s)

# %%
s.clear()
print(s)

# %%
a = {} # 定义空字典
b = {'x': 3, 'y': 4}
c = {'uid': 105, 'login': 'beazley','name': 'David Beazley'}

# %%
c.keys()

# %%
c.values()

# %%
c['uid']

# %%
c['shell'] = "/bin/sh" # 重定义
print(c)

# %%
c['uid'] = 110 # 重定义
print(c)

# %%
Copy = c.copy() # 拷贝
print(Copy)

# %%
len(c) # 字典元素量

# %%
c.clear() # 清空字典
print(c)

# %%
def foo(n,*args,**kwargs):
    print("n=",n,"*args=",args,"**kwargs=",kwargs)

foo(10,23,45,name="tom",age=23)
