# %%
x=3.1415926
print(round(x,2) , round(x))
# A. 3 3.14
# B. 3.14 3
# C. 6.28 3
# D. 2 2
# Out:
# 3.14 3

# %%
s= "abcdefghijklmn"
print(s[0:10:3])
# A. behk
# B. beh
# C. adg
# D. adgj
# Out:
# adgj

# %%
s=1
for i in range(5):
    s=s*i
print(s)
# A. 0
# B. 1
# C. 5
# D. 24
# Out:
# 0

# %%
for i in range(3):
    for s in "abcd":
        if s=="c":
            break
        print (s,end="")
# A. abcabcabc
# B. aaabbbccc
# C. ababab
# D. aaabbb
# Out:
# ababab

# %%
dic={'k1':"kidd",'k2':"v2",'k3':[11,22,33]}

for key in dic.keys():
    print(key)

for value in dic.values():
    print(value)
# 输出字典

print(dic)

dic['k4']="v4"
print(dic)

dic['k1']="kidd"
print(dic)

dic['k3'].append(44)
print(dic)
#请循环输出所有的key
#请循环输出所有的value
#请在字典中添加一个键值对，‘k4’:"v4"，输出添加后的字典
#请将字典中‘k1’对应的值改为“kidd”，输出修改后的字典
#请在‘k3’对应的值中追加一个元素44，输出修改后的字典
# Out:
# k1
# k2
# k3
# kidd
# v2
# [11, 22, 33]
# {'k1': 'kidd', 'k2': 'v2', 'k3': [11, 22, 33]}
# {'k1': 'kidd', 'k2': 'v2', 'k3': [11, 22, 33], 'k4': 'v4'}
# {'k1': 'kidd', 'k2': 'v2', 'k3': [11, 22, 33], 'k4': 'v4'}
# {'k1': 'kidd', 'k2': 'v2', 'k3': [11, 22, 33, 44], 'k4': 'v4'}

# %%
# - 输入：1-7的整数，表示星期几 
#- 输出：输入整数对应的星期字符串 
#- 例如：输入3，输出 星期三

# %%
#WeekNamePrintV1.py
#请继续编写完成以上功能

week_names = ["星期一", "星期二", "星期三", "星期四", "星期五", "星期六", "星期日"]
week_names1 =  "星期一星期二星期三星期四星期五星期六星期日"
weekId = eval(input("请输入星期数字(1-7)："))

# if 1 <= weekId <= 7:
#     print(week_names[weekId - 1])
# else:
#     print("输入错误，请输入1-7的整数。")

if 1 <= weekId <= 7:
    print(week_names1[weekId*3-3:weekId*3])
else:
    print("输入错误，请输入1-7的整数。")
# Out:
# 星期三
