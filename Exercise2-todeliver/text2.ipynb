# %%
import os
from osgeo import ogr
driver=ogr.GetDriverByName('ESRI Shapefile')
os.chdir("D:/learnpy/learnOpengis-1/Exercise3-todeliver")
inshp = "./data-Exercise3/sites.shp"
datasource = ogr.Open(inshp)
driver = datasource.GetDriver()
layer_in = datasource.GetLayer(0)
# Out:
# d:\learnpy\learnOpengis-1\.venv\Lib\site-packages\osgeo\ogr.py:601: FutureWarning: Neither ogr.UseExceptions() nor ogr.DontUseExceptions() has been explicitly called. In GDAL 4.0, exceptions will be enabled by default.
#   warnings.warn(

# %%
driver=ogr.GetDriverByName('ESRI Shapefile')
outshp = "./data-Exercise3/trees.shp"
ds = driver.CreateDataSource(outshp)
layer_out=ds.CreateLayer('trees_poi',geom_type=ogr.wkbPoint)

# %%
layer_defn = layer_in.GetLayerDefn()
for i in range(layer_defn.GetFieldCount()):
    field_defn = layer_defn.GetFieldDefn(i)
    layer_out.CreateField(field_defn)
    print(field_defn.GetName())
# Out:
# ID
# COVER

# %%
featureDefn = layer_out.GetLayerDefn()
feature = ogr.Feature(featureDefn)

# %%
print(featureDefn.GetName())
# Out:
# trees

# %%
layer_in.ResetReading()
feature_in = layer_in.GetNextFeature()
while feature_in:
    if feature_in.GetField('COVER') == 'trees':
       feature.SetField('id', feature_in.GetField('id'))
       feature.SetField('COVER', feature_in.GetField('COVER'))

       geometry = feature.GetGeometryRef()

       if geometry is not None:
            feature.SetGeometry(geometry.Clone())

       layer_out.CreateFeature(feature)

    feature = layer_in.GetNextFeature()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 4
#       1 layer_in.ResetReading()
#       2 feature_in = layer_in.GetNextFeature()
#       3 while feature_in:
# ----> 4     if feature_in.GetField('COVER') == 'trees':
#       5        feature.SetField('id', feature_in.GetField('id'))
#       6        feature.SetField('COVER', feature_in.GetField('COVER'))
#       7
#
# File d:\learnpy\learnOpengis-1\.venv\Lib\site-packages\osgeo\ogr.py:3829, in Feature.GetField(self, fld_index)
#    3798 """
#    3799 Get the value of a field in its native type.
#    3800
#    (...)   3826 168
#    3827 """
#    3828 if isinstance(fld_index, str):
# -> 3829     fld_index = self._getfieldindex(fld_index)
#    3830 if (fld_index < 0) or (fld_index > self.GetFieldCount()):
#    3831     raise KeyError("Illegal field requested in GetField()")
#
# File d:\learnpy\learnOpengis-1\.venv\Lib\site-packages\osgeo\ogr.py:3717, in Feature._getfieldindex(self, fieldname)
#    3715 case_insensitive_idx = -1
#    3716 fdefn = _ogr.Feature_GetDefnRef(self)
# -> 3717 for i in range(fdefn.GetFieldCount()):
#    3718     name = fdefn.GetFieldDefn(i).GetName()
#    3719     if name == fieldname:
#
# File d:\learnpy\learnOpengis-1\.venv\Lib\site-packages\osgeo\ogr.py:4097, in FeatureDefn.GetFieldCount(self, *args)
#    4082 def GetFieldCount(self, *args):
#    4083     r"""
#    4084     GetFieldCount(FeatureDefn self) -> int
#    4085
#    (...)   4095
#    4096     """
# -> 4097     return _ogr.FeatureDefn_GetFieldCount(self, *args)
#
# KeyboardInterrupt:
